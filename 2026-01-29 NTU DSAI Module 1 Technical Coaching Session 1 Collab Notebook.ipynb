# %% [markdown]
# <a href="https://colab.research.google.com/github/Gohshg/NTU-DSAI-Module-1.4-SQL-Basic-DML/blob/main/2026-01-29%20NTU%20DSAI%20Module%201%20Technical%20Coaching%20Session%201%20Collab%20Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, GitHub! This is my first commit.")
# Out:
# Hello, GitHub! This is my first commit.
